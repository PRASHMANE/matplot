# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={'student':['prash','mane','bhumi','chandu'],
     'fees':[1000,2300,4000,5500],
     'schlorship':[10000,15000,2000,4000]}
data=pd.DataFrame(data)
data
# Out:
#   student  fees  schlorship
# 0   prash  1000       10000
# 1    mane  2300       15000
# 2   bhumi  4000        2000
# 3  chandu  5500        4000

# %%
# adding xlabel() annd ylabel()

# %%
x=data.fees
y=data.schlorship
plt.plot(x,y,color='r')
plt.xlabel('fees')
plt.ylabel('schlorship')
plt.show()
