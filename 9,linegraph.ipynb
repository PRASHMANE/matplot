# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mon=np.array(['jan','feb','mar','april','may','june','july'])
temp=np.array([89,96,45,34,87,23,27])

# %%
plt.plot(mon,temp)
plt.legend(labels='temp')
plt.xlabel('mon')
plt.ylabel('temp')
plt.show()
