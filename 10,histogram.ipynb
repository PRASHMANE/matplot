# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
marks=np.array([10,15,20,25,12,56,97])

# %%
plt.hist(marks,bins=[0,20,40,60,80])
plt.legend(labels='marks')
plt.xlabel('student')
plt.ylabel('marks')
plt.show()
