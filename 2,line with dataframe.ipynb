# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data={'student':['prash','mane','bhumi','chandu'],
     'fees':[1000,2300,4000,5500],
     'schlorship':[100000,20000,30000,4000]}
data=pd.DataFrame(data)
data
# Out:
#   student  fees  schlorship
# 0   prash  1000      100000
# 1    mane  2300       20000
# 2   bhumi  4000       30000
# 3  chandu  5500        4000

# %%
x=data['fees']
y=data['schlorship']
plt.plot(x,y)
plt.show()
