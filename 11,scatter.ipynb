# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
temp1=np.array([25,47,34,38,27,40,42,18])
temp2=np.array([7,22,40,29,27,10,19,31])

# %%
score_rate=np.array([5,10,15,20,25,30,35,40])

# %%
plt.scatter(temp1,score_rate,color='r')
plt.scatter(temp2,score_rate,color='b')
plt.xlabel('team_score')
plt.ylabel('score_rate')
plt.show()
